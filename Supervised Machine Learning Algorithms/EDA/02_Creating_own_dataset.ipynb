# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Create Dataframe and Read the dataset using Pandas
# dataset = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header = 1)
# dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
# Convert Dataframe into Dictionary as MongoDB stores data in records/documents
# data = dataset.to_dict(orient = 'records')

# %%
# Insert records in the dataset into MongoDB collection "hotel_records"
# db.fire_records.insert_many(data)
# print("All the Data has been Exported to MongoDB Successfully")

# %%
# Sample list of dictionaries
list_cursor =  [
    {'id': 1, 'name': 'Luke', 'age': 36, 'occupation': 'Consultant', 'city': 'Charlotte', 'salary': 95000, 'education': 'Master'},
    {'id': 2, 'name': 'Hannah', 'age': 25, 'occupation': 'Research Scientist', 'city': 'Raleigh', 'salary': 85000, 'education': 'PhD'},
    {'id': 3, 'name': 'Jackson', 'age': 34, 'occupation': 'Entrepreneur', 'city': 'Austin', 'salary': None, 'education': 'Bachelor'},
    {'id': 4, 'name': 'Sarah', 'age': 28, 'occupation': 'Engineer', 'city': 'New York', 'salary': 75000, 'education': 'Bachelor'},
    {'id': 5, 'name': 'Michael', 'age': 40, 'occupation': 'Doctor', 'city': 'Los Angeles', 'salary': 120000, 'education': 'MD'},
    {'id': 6, 'name': 'Emily', 'age': 22, 'occupation': 'Student', 'city': 'Chicago', 'salary': None, 'education': 'Undergraduate'},
    {'id': 7, 'name': 'David', 'age': 33, 'occupation': 'Software Engineer', 'city': 'San Francisco', 'salary': 90000, 'education': 'Master'},
    {'id': 8, 'name': 'Olivia', 'age': 29, 'occupation': 'Teacher', 'city': 'Boston', 'salary': 60000, 'education': 'Bachelor'},
    {'id': 9, 'name': 'Daniel', 'age': 45, 'occupation': 'Lawyer', 'city': 'Washington D.C.', 'salary': 150000, 'education': 'JD'},
    {'id': 10, 'name': 'Sophia', 'age': 27, 'occupation': 'Marketing Manager', 'city': 'Seattle', 'salary': 80000, 'education': 'Master'},
    {'id': 11, 'name': 'Ethan', 'age': 32, 'occupation': 'Financial Analyst', 'city': 'Houston', 'salary': 85000, 'education': 'Bachelor'},
    {'id': 12, 'name': 'Ava', 'age': 26, 'occupation': 'Graphic Designer', 'city': 'Miami', 'salary': 65000, 'education': 'Bachelor'},
    {'id': 13, 'name': 'James', 'age': 38, 'occupation': 'Chef', 'city': 'Atlanta', 'salary': 70000, 'education': 'Culinary School'},
    {'id': 14, 'name': 'Grace', 'age': 31, 'occupation': 'HR Manager', 'city': 'Dallas', 'salary': 75000, 'education': 'Master'},
    {'id': 15, 'name': 'Logan', 'age': 29, 'occupation': 'Sales Representative', 'city': 'Phoenix', 'salary': 70000, 'education': 'Bachelor'},
    {'id': 16, 'name': 'Chloe', 'age': 24, 'occupation': 'Nurse', 'city': 'Philadelphia', 'salary': 60000, 'education': 'Bachelor'},
    {'id': 17, 'name': 'William', 'age': 37, 'occupation': 'Architect', 'city': 'Denver', 'salary': 100000, 'education': 'Master'},
    {'id': 18, 'name': 'Lily', 'age': 30, 'occupation': 'Event Planner', 'city': 'San Diego', 'salary': 80000, 'education': 'Bachelor'},
    {'id': 19, 'name': 'Lucas', 'age': 28, 'occupation': 'Journalist', 'city': 'Portland', 'salary': 65000, 'education': 'Bachelor'},
    {'id': 20, 'name': 'Madison', 'age': 33, 'occupation': 'Real Estate Agent', 'city': 'Detroit', 'salary': 90000, 'education': 'Bachelor'}
]
df = pd.DataFrame(list_cursor)
df.drop('id', axis = 1, inplace = True)
df
# Out:
#        name  age            occupation             city    salary  \
# 0      Luke   36            Consultant        Charlotte   95000.0
# 1    Hannah   25    Research Scientist          Raleigh   85000.0
# 2   Jackson   34          Entrepreneur           Austin       NaN
# 3     Sarah   28              Engineer         New York   75000.0
# 4   Michael   40                Doctor      Los Angeles  120000.0
# 5     Emily   22               Student          Chicago       NaN
# 6     David   33     Software Engineer    San Francisco   90000.0
# 7    Olivia   29               Teacher           Boston   60000.0
# 8    Daniel   45                Lawyer  Washington D.C.  150000.0
# 9    Sophia   27     Marketing Manager          Seattle   80000.0
# 10    Ethan   32     Financial Analyst          Houston   85000.0
# 11      Ava   26      Graphic Designer            Miami   65000.0
# 12    James   38                  Chef          Atlanta   70000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        20 non-null     object
#  1   age         20 non-null     int64
#  2   occupation  20 non-null     object
#  3   city        20 non-null     object
#  4   salary      18 non-null     float64
#  5   education   20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# Data Cleaning

# %%
# Column which has null values
df[df.isnull().any(axis = 1)]
# Out:
#       name  age    occupation     city  salary      education
# 2  Jackson   34  Entrepreneur   Austin     NaN       Bachelor
# 5    Emily   22       Student  Chicago     NaN  Undergraduate

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'occupation', 'city', 'salary', 'education', 'Expense'], dtype='object')

# %%
print(df.head())
# Out:
#       name  age          occupation         city    salary education  Expense
# 0     Luke   36          Consultant    Charlotte   95000.0    Master      1.0
# 1   Hannah   25  Research Scientist      Raleigh   85000.0       PhD      1.0
# 2  Jackson   34        Entrepreneur       Austin       NaN  Bachelor      1.0
# 3    Sarah   28            Engineer     New York   75000.0  Bachelor      1.0
# 4  Michael   40              Doctor  Los Angeles  120000.0        MD      1.0

# %%
# Add new column with expense
df.loc[:122,'Expense'] = 30000
df.loc[122:,'Expense'] = 20000
df[['Expense']] = df[['Expense']].astype(int)

# %%
df.isnull().sum()
# Out:
# name          0
# age           0
# occupation    0
# city          0
# salary        0
# education     0
# Expense       0
# dtype: int64

# %%
# Remove null or no values rows
df = df.dropna().reset_index(drop = True)
df.shape
# Out:
# (18, 7)

# %%
# Column which has string
df.iloc[[15]]
# Out:
#     name  age     occupation       city   salary education  Expense
# 15  Lily   30  Event Planner  San Diego  80000.0  Bachelor    30000

# %%
# Remove 15th column
df = df.drop(15).reset_index(drop = True)

# %%
# List out column names to check
df.columns
# Out:
# Index(['name', 'age', 'occupation', 'city', 'salary', 'education', 'Expense'], dtype='object')

# %%
# If space is found spaces are fixed as
# df.columns = df.columns.str.strip()
#df.columns

# %%
# Changing the required columns as integer data type
df[['age','salary','Expense']] = df[['age','salary','Expense']].astype(int)

# %%
# Final datatypes check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   age         17 non-null     int64
#  2   occupation  17 non-null     object
#  3   city        17 non-null     object
#  4   salary      17 non-null     int64
#  5   education   17 non-null     object
#  6   Expense     17 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ KB

# %%
df.describe().T
# Out:
#          count          mean           std      min      25%      50%  \
# age       17.0     31.823529      5.790459     24.0     28.0     31.0
# salary    17.0  84411.764706  23108.599112  60000.0  70000.0  80000.0
# Expense   17.0  30000.000000      0.000000  30000.0  30000.0  30000.0
#
#              75%       max
# age         36.0      45.0
# salary   90000.0  150000.0
# Expense  30000.0   30000.0

# %%
df[:15]
# Out:
#        name  age            occupation             city  salary  \
# 0      Luke   36            Consultant        Charlotte   95000
# 1    Hannah   25    Research Scientist          Raleigh   85000
# 2     Sarah   28              Engineer         New York   75000
# 3   Michael   40                Doctor      Los Angeles  120000
# 4     David   33     Software Engineer    San Francisco   90000
# 5    Olivia   29               Teacher           Boston   60000
# 6    Daniel   45                Lawyer  Washington D.C.  150000
# 7    Sophia   27     Marketing Manager          Seattle   80000
# 8     Ethan   32     Financial Analyst          Houston   85000
# 9       Ava   26      Graphic Designer            Miami   65000
# 10    James   38                  Chef          Atlanta   70000
# 11    Grace   31            HR Manager           Dallas   75000
# 12    Logan   29  Sales Representative          Phoenix   70000
# 13    Chloe   24                 Nurse     Philadelphia   60000
# ...

# %%
df[15:]
# Out:
#        name  age         occupation      city  salary education  Expense
# 15    Lucas   28         Journalist  Portland   65000  Bachelor    30000
# 16  Madison   33  Real Estate Agent   Detroit   90000  Bachelor    30000

# %%
df
# Out:
#        name  age            occupation             city  salary  \
# 0      Luke   36            Consultant        Charlotte   95000
# 1    Hannah   25    Research Scientist          Raleigh   85000
# 2     Sarah   28              Engineer         New York   75000
# 3   Michael   40                Doctor      Los Angeles  120000
# 4     David   33     Software Engineer    San Francisco   90000
# 5    Olivia   29               Teacher           Boston   60000
# 6    Daniel   45                Lawyer  Washington D.C.  150000
# 7    Sophia   27     Marketing Manager          Seattle   80000
# 8     Ethan   32     Financial Analyst          Houston   85000
# 9       Ava   26      Graphic Designer            Miami   65000
# 10    James   38                  Chef          Atlanta   70000
# 11    Grace   31            HR Manager           Dallas   75000
# 12    Logan   29  Sales Representative          Phoenix   70000
# 13    Chloe   24                 Nurse     Philadelphia   60000
# ...

# %%
# Dropping  Expense Feature
df1 = df.drop(['Expense'], axis = 1)

# %%
# Encoding Bachelor as 0 and other as 1
df1['education'] = np.where(df1['education'] == 'Bachelor',0,1)

# %%
# Plot density plot for all features
plt.style.use('seaborn')
df1.hist(bins = 20, figsize = (20,15), ec = 'b')
plt.show()
