# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the dataset
df = pd.read_csv('exams.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1  female        group D          associate's degree      standard
# 2  female        group B          associate's degree  free/reduced
# 3  female        group E          associate's degree      standard
# 4    male        group D                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          37             38             41
# 1                    none          61             71             79
# 2                    none          55             64             57
# 3                    none          67             62             60
# 4               completed          54             57             59

# %%
df.shape
# Out:
# (1000, 8)

# %%
# Check missing values
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Checking the number of unique values of each columns
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     73
# reading score                  71
# writing score                  75
# dtype: int64

# %%
# Check the statistics of the dataset
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000     1000.00000
# mean     66.01100      68.908000       67.57000
# std      15.12328      14.664057       15.54879
# min      24.00000      28.000000       22.00000
# 25%      55.00000      58.750000       57.00000
# 50%      66.00000      68.000000       67.00000
# 75%      76.25000      79.000000       78.00000
# max     100.00000     100.000000      100.00000

# %%
# Explore more info about the data
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1  female        group D          associate's degree      standard
# 2  female        group B          associate's degree  free/reduced
# 3  female        group E          associate's degree      standard
# 4    male        group D                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          37             38             41
# 1                    none          61             71             79
# 2                    none          55             64             57
# 3                    none          67             62             60
# 4               completed          54             57             59

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 995  female        group C           bachelor's degree  standard
# 996    male        group D            some high school  standard
# 997    male        group D                 high school  standard
# 998    male        group C          associate's degree  standard
# 999    male        group C           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 995                    none          76             85             87
# 996                    none          63             69             58
# 997                    none          74             64             58
# 998                    none          74             78             67
# 999               completed          89             82             88

# %%
df.tail(100)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 900    male        group E           bachelor's degree      standard
# 901  female        group C                 high school  free/reduced
# 902    male        group B                 high school  free/reduced
# 903  female        group D          associate's degree  free/reduced
# 904    male        group C            some high school      standard
# ..      ...            ...                         ...           ...
# 995  female        group C           bachelor's degree      standard
# 996    male        group D            some high school      standard
# 997    male        group D                 high school      standard
# 998    male        group C          associate's degree      standard
# 999    male        group C           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 900                    none          99             88             97
# 901               completed          59             75             74
# 902               completed          67             64             64
# 903                    none          61             72             69
# 904                    none          63             52             49
# ..                      ...         ...            ...            ...
# 995                    none          76             85             87
# 996                    none          63             69             58
# 997                    none          74             64             58
# 998                    none          74             78             67
# 999               completed          89             82             88
#
# [100 rows x 8 columns]

# %%
df.head(100)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group D                some college      standard
# 1   female        group D          associate's degree      standard
# 2   female        group B          associate's degree  free/reduced
# 3   female        group E          associate's degree      standard
# 4     male        group D                some college  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group C            some high school  free/reduced
# 96    male        group C            some high school      standard
# 97    male        group B            some high school      standard
# 98    male        group C                 high school      standard
# 99  female        group C                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          37             38             41
# 1                     none          61             71             79
# 2                     none          55             64             57
# 3                     none          67             62             60
# 4                completed          54             57             59
# ..                     ...         ...            ...            ...
# 95               completed          46             55             59
# 96                    none          49             35             23
# 97                    none          63             62             56
# 98                    none          66             64             64
# 99                    none          72             73             73
#
# [100 rows x 8 columns]

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numerical_feature
# Out:
# ['math score', 'reading score', 'writing score']

# %%
categorical_feature
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df['gender'].value_counts()
# Out:
# gender
# female    506
# male      494
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    326
# group D    256
# group B    211
# group E    137
# group A     70
# Name: count, dtype: int64

# %%
# Aggregate the total score with mean

df['total_score'] = (df['math score'] + df['reading score'] + df['writing score'])
df['average'] = df['total_score'] / 3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1  female        group D          associate's degree      standard
# 2  female        group B          associate's degree  free/reduced
# 3  female        group E          associate's degree      standard
# 4    male        group D                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          37             38             41
# 1                    none          61             71             79
# 2                    none          55             64             57
# 3                    none          67             62             60
# 4               completed          54             57             59
#
#    total_score    average
# 0          116  38.666667
# 1          211  70.333333
# 2          176  58.666667
# 3          189  63.000000
# 4          170  56.666667

# %%
# Exploring More Visualization
fig, axis = plt.subplots(1, 2, figsize = (15, 7))
plt.subplot(121)
sns.histplot(data = df, x= 'average', bins = 30, kde = True, color = 'g')
plt.subplot(122)
sns.histplot(data = df, x= 'average', bins = 30, kde = True, hue = 'gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# **Insights**
# - Female students tends to perform well than male students

# %%
plt.subplots(1, 3, figsize = (25,6))
plt.subplot(141)
sns.histplot(data = df, x = 'average', kde = True, hue = 'lunch')
plt.subplot(142)
sns.histplot(data = df[df.gender == 'female'], x = 'average', kde = True, hue = 'lunch')
plt.subplot(143)
sns.histplot(data = df[df.gender == 'male'], x = 'average', kde = True, hue = 'lunch')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# **Insights**
# - Standard Lunch help students perform well in exams\
# - Standard lunch helps perform well in exams be it a male or female

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1  female        group D          associate's degree      standard
# 2  female        group B          associate's degree  free/reduced
# 3  female        group E          associate's degree      standard
# 4    male        group D                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          37             38             41
# 1                    none          61             71             79
# 2                    none          55             64             57
# 3                    none          67             62             60
# 4               completed          54             57             59
#
#    total_score    average
# 0          116  38.666667
# 1          211  70.333333
# 2          176  58.666667
# 3          189  63.000000
# 4          170  56.666667

# %%
plt.subplots(1, 3, figsize = (25,6))
plt.subplot(141)
sns.histplot(data = df, x = 'average', kde = True, hue = 'parental level of education')
plt.subplot(142)
sns.histplot(data = df[df.gender == 'female'], x = 'average', kde = True, hue = 'parental level of education')
plt.subplot(143)
sns.histplot(data = df[df.gender == 'male'], x = 'average', kde = True, hue = 'parental level of education')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
plt.subplots(1, 3, figsize = (25,6))
plt.subplot(141)
ax = sns.histplot(data = df, x = 'average', kde = True, hue = 'race/ethnicity')
plt.subplot(142)
ax = sns.histplot(data = df[df.gender == 'female'], x = 'average', kde = True, hue = 'race/ethnicity')
plt.subplot(143)
ax = sns.histplot(data = df[df.gender == 'male'], x = 'average', kde = True, hue = 'race/ethnicity')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot = True)
# Out:
# <Axes: >
