# %%
'''You are a data scientist at a retail company and the marketing
team is look to optimize their poromotion campaigns by targeting
specific customer segments. The goal is to identify distinct groups
of customer based on their demographic information such as age,
income, and spending hours
'''
# Out:
# 'You are a data scientist at a retail company and the marketing\nteam is look to optimize their poromotion campaigns by targeting \nspecific customer segments. The goal is to identify distinct groups\nof customer based on their demographic information such as age, \nincome, and spending hours\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %%
# creating a dataset
np.random.seed(42)
data = pd.DataFrame({'Age' :  np.random.randint(18, 65, 100),
                    'Income' : np.random.randint(30000, 100000, 100),
                    'Spending_Score' : np.random.randint(1, 100, 100)
                    })
print(data)
# Out:
#     Age  Income  Spending_Score
# 0    56   32695              59
# 1    46   78190              36
# 2    32   35258              19
# 3    60   69504              90
# 4    25   63159              67
# ..  ...     ...             ...
# 95   24   55184              97
# 96   26   72107              69
# 97   41   81663              61
# 98   18   45708              48
# 99   61   79811              19
#
# [100 rows x 3 columns]

# %%
# for standardization
scaler= StandardScaler()
scaler_data = scaler.fit_transform(data)

# %%
# Fit the clustering model with the new data
clustering = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
data['Cluster'] = clustering.fit_predict(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
plt.scatter(data['Income'], data['Spending_Score'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Income')
plt.ylabel('Spending_score')
plt.title('Customer Segmentaion')
plt.show()
