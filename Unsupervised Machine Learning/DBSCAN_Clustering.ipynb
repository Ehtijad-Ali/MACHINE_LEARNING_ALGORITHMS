# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import warnings

warnings.filterwarnings('ignore')

# %%
x, y =make_moons(n_samples=250, noise=0.05)

# %%
df = {'data1': x[:, 0], 'data2': x[:, 1], 'output': y}

# %%
dataset = pd.DataFrame(df)
dataset
# Out:
#         data1     data2  output
# 0    0.214184  0.926460       0
# 1    0.866909 -0.506748       1
# 2    1.916906  0.003445       1
# 3    0.418071 -0.442362       1
# 4    0.943580 -0.585666       1
# ..        ...       ...     ...
# 245  1.951666  0.209793       1
# 246  1.005834  0.319881       0
# 247  0.190942  0.030298       1
# 248  0.277068 -0.227400       1
# 249 -0.735231  0.611136       0
#
# [250 rows x 3 columns]

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.5, min_samples=5)
dataset['predict']=db.fit_predict(dataset)

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset, hue='predict')
plt.show()

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset, hue=y)
plt.show()
